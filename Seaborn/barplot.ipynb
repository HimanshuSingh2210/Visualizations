# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_df=sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x=tips_df['day'],y=tips_df['total_bill'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#hue
sns.barplot(x=tips_df['day'],y=tips_df['total_bill'],hue=tips_df['sex'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#not need to write dataframe again again so we will use data
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
order=['sun','thur','fri','sat']

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df, order = order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
hue_order=['female','male']
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df, hue_order=hue_order)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df, hue_order=hue_order,estimator=mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 sns.barplot(x='day',y='total_bill',hue='sex',
# ----> 2             data=tips_df, hue_order=hue_order,estimator=mean)
#
# NameError: name 'hue_order' is not defined

# %%
import numpy as np

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df,estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df,estimator=np.max)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df,ci=12)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16524\247107148.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 12)` for the same effect.
#
#   sns.barplot(x='day',y='total_bill',hue='sex',
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',
            data=tips_df,n_boot=2)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,color='g')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,palette='magma')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,saturation=.3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,errcolor='g')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,errwidth=12
           )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
kwargs={'alpha':0.9,'linestyle':':','linewidth':5,'edgecolor':'k'}

sns.barplot(x='day',y='total_bill',hue='sex',data=tips_df,**kwargs)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set()
sns.barplot(x='day',y='total_bill',data=tips_df,**kwargs)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# kwargs are alpha,linestyle,edgecolor,linewidth etc etc and
# we can pass this as parameter which was done in bar chart of matplot
