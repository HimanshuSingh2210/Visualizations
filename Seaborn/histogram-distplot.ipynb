# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm

# %%
Tips=sns.load_dataset('tips')

# %%
Tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(Tips['size'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\878683330.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['size'])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.distplot(Tips['tip'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3176278510.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(Tips['total_bill'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\575360522.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(Tips['size'])
sns.distplot(Tips['total_bill'])
sns.distplot(Tips['tip'])
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3869689428.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['size'])
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3869689428.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'])
# ...

# %%
'''sns.distplot(
    a=None,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
    x=None,
)'''

# %%
sns.distplot(Tips['total_bill'],bins=10)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3809901618.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# hist bydefault=True but when it is False the we get only KDE(kernel density estimator)/line plot
sns.distplot(Tips['total_bill'],bins=10,hist=False)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3005596772.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10,hist=False)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# kde bydefault=True but when it is False the we get only histogram
sns.distplot(Tips['total_bill'],bins=10,kde=False)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\995299078.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10,kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(Tips['total_bill'],bins=10,rug=True)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3996696438.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10,rug=True)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
from scipy.stats import norm

# %%
# norm is used for just normalise plot unde fit
sns.distplot(Tips['total_bill'],bins=10,fit=norm)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\476290682.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10,fit=norm)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# remove kde and just want norm

sns.distplot(Tips['total_bill'],bins=10,fit=norm,kde=False)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\1448436945.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=10,fit=norm,kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(Tips['total_bill'],color="r")
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\425077938.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],color="r")
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(Tips['total_bill'],color="y",vertical=True)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\2978438466.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],color="y",vertical=True)
# <Axes: xlabel='Density', ylabel='total_bill'>

# %%
sns.distplot(Tips['total_bill'],axlabel="TOTALBILL")
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\123761544.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],axlabel="TOTALBILL")
# <Axes: xlabel='TOTALBILL', ylabel='Density'>

# %%
sns.distplot(Tips['total_bill'],label="TOTAL BILL VS DENSITY")
plt.legend()
plt.title("TOTAL BILL VS DENSITY")
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3389765462.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],label="TOTAL BILL VS DENSITY")
# Text(0.5, 1.0, 'TOTAL BILL VS DENSITY')

# %%
# sns.set() bydefault provide grid
plt.figure(figsize=(16,9))
sns.distplot(Tips['total_bill'],label="TOTAL BILL VS DENSITY")
sns.set()
plt.legend()
plt.title("TOTAL BILL VS DENSITY")
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\545711053.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],label="TOTAL BILL VS DENSITY")
# Text(0.5, 1.0, 'TOTAL BILL VS DENSITY')

# %%
Tips.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins=[5,10,15,20,25,30,35,40,45,50,55]

# %%
sns.distplot(Tips['total_bill'],bins=bins)
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\4258951610.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=bins)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#ticks we have used in matplot in bar charts
sns.distplot(Tips['total_bill'],bins=bins)
plt.xticks(bins,rotation=30)
plt.show()
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3407989015.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],bins=bins)

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9})
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\2271973786.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde_kws={'color':'#8e00ce','linewidth':8,
                      'linestyle':'--','alpha':0.9}
            )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\908353666.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde_kws={'color':'#8e00ce','linewidth':8,
                      'linestyle':'--','alpha':0.9},
             
             rug=True
             
             )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\2512092663.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde_kws={'color':'#8e00ce','linewidth':8,
                      'linestyle':'--','alpha':0.9},
             
             rug=True,
             
             rug_kws={'color':'#0426d0','edgecolor':'#00dbff','linewidth':8,
                      'linestyle':'--','alpha':0.9}
             
             )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\1191601121.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde=False,
             rug=True,
             
             rug_kws={'color':'#0426d0','edgecolor':'#00dbff','linewidth':8,
                      'linestyle':'--','alpha':0.9}
             
             )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3618473443.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde=False,
             
            fit=norm,
             
             rug=True,
             
             rug_kws={'color':'#0426d0','edgecolor':'#00dbff','linewidth':8,
                      'linestyle':'--','alpha':0.9}
             
             )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\2056559005.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill'>

# %%
plt.figure(figsize=(16,9))
sns.set()

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde=False,
             
             fit=norm,
             
             fit_kws={'color':'#8e00ce','linewidth':5,
                      'linestyle':'--','alpha':0.4},
             rug=True,
             
             rug_kws={'color':'#0426d0','edgecolor':'#00dbff','linewidth':8,
                      'linestyle':'--','alpha':0.9}
             
             )
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\3614615610.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: xlabel='total_bill'>

# %%
plt.figure(figsize=(16,9))
sns.set()
plt.legend()
plt.title("TOTAL BILL VS DENSITY")
plt.ylabel('density')

sns.distplot(Tips['total_bill'],
            hist_kws={'color':'#dc143c','edgecolor':'#aaff00','linewidth':5,
                      'linestyle':'--','alpha':0.9},
            
            kde=False,
             
             fit=norm,
             
             fit_kws={'color':'#8e00ce','linewidth':5,
                      'linestyle':'--','alpha':0.4},
             rug=True,
             
             rug_kws={'color':'#0426d0','edgecolor':'#00dbff','linewidth':8,
                      'linestyle':'--','alpha':0.9}
             
             )
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\singh\AppData\Local\Temp\ipykernel_16052\2210054714.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Tips['total_bill'],
# <Axes: title={'center': 'TOTAL BILL VS DENSITY'}, xlabel='total_bill', ylabel='density'>
